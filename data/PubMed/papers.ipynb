# %%
import os
import xml.etree.ElementTree as ET
import json

# Path to your directory containing XML files
DIR_PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx"
OUTPUT_FILE = "papers.json"

# Function to extract all text within an element, including text in child elements
def extract_text(element):
    return ''.join(element.itertext()).strip()

# Function to extract title, abstract, and PMID from an XML file
def extract_article_info(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Extract PMID
        pmid_element = root.find('.//article-id[@pub-id-type="pmid"]')
        pmid = pmid_element.text.strip() if pmid_element is not None else None

        if pmid is None:
            print(f"Skipping article with no PMID: {file_path}")
            return None

        # Extract title
        title_element = root.find('.//article-title')
        title = extract_text(title_element) if title_element is not None else 'No title found'

        # Extract abstract
        abstract_element = root.find('.//abstract')
        abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

        return {pmid: {"title": title, "abstract": abstract}}
    except ET.ParseError:
        print(f"Skipping invalid XML file: {file_path}")
        return None

# Collect all articles' information
articles = {}

# Iterate through all XML files in the directory and extract information
for file_name in os.listdir(DIR_PATH):
    if file_name.endswith('.xml'):
        file_path = os.path.join(DIR_PATH, file_name)
        article_info = extract_article_info(file_path)
        if article_info:  # Only add if article_info is not None
            articles.update(article_info)

# Write the collected data to a JSON file
with open(OUTPUT_FILE, 'w') as json_file:
    json.dump(articles, json_file, indent=4)

print(f"Extracted data has been written to {OUTPUT_FILE}")
# Out:
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1802624.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1697742.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1942176.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1802625.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1876605.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1942173.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1978239.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1942172.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1933172.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1876610.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1802634.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1899101.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1994800.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1994792.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1885658.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1770951.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1887696.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1557809.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1888799.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1513143.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1874626.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1538845.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1976437.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1904261.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1904259.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1802628.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1851660.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1904264.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1513152.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1978232.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1472625.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1874637.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1887783.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1810366.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1828438.xml
# Skipping article with no PMID: /Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1807975.xml
# Extracted data has been written to paper.json

# %%
with open("papers.json", 'r') as json_file:
    loaded_articles = json.load(json_file)

# %%
num_elements = len(loaded_articles)
print(f"Number of elements in {OUTPUT_FILE}: {num_elements}")
# Out:
# Number of elements in paper.json: 1621

# %%
import os
import xml.etree.ElementTree as ET
import json

# Path to your directory containing XML files
DIR_PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx"
OUTPUT_FILE = "papers.json"

# Function to extract all text within an element, including text in child elements
def extract_text(element):
    return ''.join(element.itertext()).strip()

# Function to extract title and abstract from an XML file
def extract_article_info(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Extract title
        title_element = root.find('.//article-title')
        title = extract_text(title_element) if title_element is not None else 'No title found'

        # Extract abstract
        abstract_element = root.find('.//abstract')
        abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

        return {"title": title, "abstract": abstract}
    except ET.ParseError:
        print(f"Skipping invalid XML file: {file_path}")
        return None

# Collect all articles' information
articles = []

# Iterate through all XML files in the directory and extract information
for file_name in os.listdir(DIR_PATH):
    if file_name.endswith('.xml'):
        file_path = os.path.join(DIR_PATH, file_name)
        article_info = extract_article_info(file_path)
        if article_info:  # Only append if article_info is not None
            articles.append(article_info)

# Write the collected data to a JSON file
with open(OUTPUT_FILE, 'w') as json_file:
    json.dump(articles, json_file, indent=4)

print(f"Extracted data has been written to {OUTPUT_FILE}")
# Out:
# Extracted data has been written to papers.json

# %%
import json

# Path to the JSON file
OUTPUT_FILE = "papers.json"

# Load the JSON file
with open(OUTPUT_FILE, 'r') as file:
    papers = json.load(file)

# Get the number of elements
num_elements = len(papers)

# Get an example of a title and abstract
example_paper = papers[0] if papers else None

print(f"Number of elements in paper.json: {num_elements}")
if example_paper:
    print("Example paper:")
    print(f"Title: {example_paper['title']}")
    print(f"Abstract: {example_paper['abstract']}")
else:
    print("No papers found.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 14
#      11 num_elements = len(papers)
#      13 # Get an example of a title and abstract
# ---> 14 example_paper = papers[0] if papers else None
#      16 print(f"Number of elements in paper.json: {num_elements}")
#      17 if example_paper:
#
# KeyError: 0

# %%
papers[1]
# Out:
# {'title': 'Expression of RAB4B, a protein governing endocytic recycling, is co-regulated with MHC class II genes',
#  'abstract': 'The small GTPase RAB4 regulates endocytic recycling, a process that contributes to Major Histocompatibility Complex (MHC)-mediated antigen presentation by specialized antigen presenting cells (APC) of the immune system. The gene encoding the RAB4B isoform of RAB4 was singled out by two complementary genome-wide screens. One of these consisted of a computer scan to identify genes containing characteristic MHC class II-related regulatory sequences. The second was the use of chromatin immunoprecipitation coupled to microarrays (ChIP-on-chip) to identify novel targets of a transcriptional co-activator called the MHC class II transactivator (CIITA). We show that the RAB4B gene is regulated by a typical MHC class II-like enhancer that is controlled directly by both CIITA and the multiprotein transcription factor complex known as the MHC class II enhanceosome. RAB4B expression is thus activated by the same regulatory machinery that is known to be essential for the expression of MHC class II genes. This molecular link between the transcriptional activation of RAB4B and MHC class II genes implies that APC boost their antigen presentation capacity by increasing RAB4-mediated endocytic recycling.'}

# %%
import os
import xml.etree.ElementTree as ET
import json

# Path to your directory containing XML files
DIR_PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx"
OUTPUT_FILE = "papers.json"

# Function to extract all text within an element, including text in child elements
def extract_text(element):
    return ''.join(element.itertext()).strip()

# Function to extract title and abstract from an XML file
def extract_article_info(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Extract title
        title_element = root.find('.//article-title')
        title = extract_text(title_element) if title_element is not None else 'No title found'

        # Extract abstract
        abstract_element = root.find('.//abstract')
        abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

        return {"title": title, "abstract": abstract}
    except ET.ParseError:
        return {"title": "Invalid XML", "abstract": "Invalid XML"}

# Collect all articles' information
articles = []

# Iterate through all XML files in the directory and extract information
for file_name in os.listdir(DIR_PATH):
    if file_name.endswith('.xml'):
        file_path = os.path.join(DIR_PATH, file_name)
        article_info = extract_article_info(file_path)
        articles.append(article_info)

# Write the collected data to a JSON file
with open(OUTPUT_FILE, 'w') as json_file:
    json.dump(articles, json_file, indent=4)

print(f"Extracted data has been written to {OUTPUT_FILE}")
# Out:
# Extracted data has been written to papers.json

# %%
import xml.etree.ElementTree as ET

# Path to your XML file
PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1998891.xml"

# Load and parse the XML file
tree = ET.parse(PATH)
root = tree.getroot()

# Function to extract all text within an element, including text in child elements
def extract_text(element):
    return ''.join(element.itertext()).strip()

# Extract specific information
title_element = root.find('.//article-title')
title = extract_text(title_element) if title_element is not None else 'No title found'

abstract_element = root.find('.//abstract')
abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

print(f"Title: {title}")
print(f"Abstract: {abstract}")
# Out:
# Title: The power of comparative and developmental studies for mouse models of Down syndrome
# Abstract: Since the genetic basis for Down syndrome (DS) was described, understanding the causative relationship between genes at dosage imbalance and phenotypes associated with DS has been a principal goal of researchers studying trisomy 21 (Ts21). Though inferences to the gene-phenotype relationship in humans have been made, evidence linking a specific gene or region to a particular congenital phenotype has been limited. To further understand the genetic basis for DS phenotypes, mouse models with three copies of human chromosome 21 (Hsa21) orthologs have been developed. Mouse models offer access to every tissue at each stage of development, opportunity to manipulate genetic content, and ability to precisely quantify phenotypes. Numerous approaches to recreate trisomic composition and analyze phenotypes similar to DS have resulted in diverse trisomic mouse models. A murine intraspecies comparative analysis of different genetic models of Ts21 and specific DS phenotypes reveals the complexity of trisomy and important considerations to understand the etiology of and strategies for amelioration or prevention of trisomic phenotypes. By analyzing individual phenotypes in different mouse models throughout development, such as neurologic, craniofacial, and cardiovascular abnormalities, greater insight into the gene-phenotype relationship has been demonstrated. In this review we discuss how phenotype-based comparisons between DS mouse models have been useful in analyzing the relationship of trisomy and DS phenotypes.

# %%
import json

# Path to the JSON file
OUTPUT_FILE = "paper.json"

# Load the JSON file
with open(OUTPUT_FILE, 'r') as file:
    papers = json.load(file)

# Get the number of elements
num_elements = len(papers)

# Get an example of a title and abstract
example_paper = papers[0] if papers else None

print(f"Number of elements in paper.json: {num_elements}")
if example_paper:
    print("Example paper:")
    print(f"Title: {example_paper['title']}")
    print(f"Abstract: {example_paper['abstract']}")
else:
    print("No papers found.")
# Out:
# Number of elements in paper.json: 1657
# Example paper:
# Title: Open Channel Block by Ca
# Abstract: The light-activated channels of

# %%
import os
import xml.etree.ElementTree as ET
import json

# Path to your directory containing XML files
DIR_PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx"
OUTPUT_FILE = "paper.json"

# Function to extract text from all <p> (paragraph) elements nested within a given XML element
def extract_text(element):
    abstract_parts = []
    for section in element.findall('.//p'):
        if section.text:
            abstract_parts.append(section.text.strip())
    return ' '.join(abstract_parts) if abstract_parts else 'No abstract found'

# Function to extract title and abstract from an XML file
def extract_article_info(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Extract title
        title_element = root.find('.//article-title')
        title = title_element.text.strip() if title_element is not None and title_element.text is not None else 'No title found'

        # Extract abstract
        abstract_element = root.find('.//abstract')
        abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

        return {"title": title, "abstract": abstract}
    except ET.ParseError:
        return {"title": "Invalid XML", "abstract": "Invalid XML"}

# Collect all articles' information
articles = []

# Iterate through all XML files in the directory and extract information
for file_name in os.listdir(DIR_PATH):
    if file_name.endswith('.xml'):
        file_path = os.path.join(DIR_PATH, file_name)
        article_info = extract_article_info(file_path)
        articles.append(article_info)

# Write the collected data to a JSON file
with open(OUTPUT_FILE, 'w') as json_file:
    json.dump(articles, json_file, indent=4)

print(f"Extracted data has been written to {OUTPUT_FILE}")
# Out:
# Extracted data has been written to paper.json

# %%
import os
import xml.etree.ElementTree as ET
import json

# Path to your directory containing XML files
DIR_PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx"
OUTPUT_FILE = "papers.json"

# Function to extract text from all <p> (paragraph) elements nested within a given XML element
def extract_text(element):
    abstract_parts = []
    for section in element.findall('.//p'):
        if section.text:
            abstract_parts.append(section.text.strip())
    return ' '.join(abstract_parts) if abstract_parts else 'No abstract found'

# Function to extract title and abstract from an XML file
def extract_article_info(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Extract title
        title_element = root.find('.//article-title')
        title = title_element.text.strip() if title_element is not None else 'No title found'

        # Extract abstract
        abstract_element = root.find('.//abstract')
        abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

        return {"title": title, "abstract": abstract}
    except ET.ParseError:
        return {"title": "Invalid XML", "abstract": "Invalid XML"}

# Collect all articles' information
articles = []

# Iterate through all XML files in the directory and extract information
for file_name in os.listdir(DIR_PATH):
    if file_name.endswith('.xml'):
        file_path = os.path.join(DIR_PATH, file_name)
        article_info = extract_article_info(file_path)
        articles.append(article_info)

# Write the collected data to a JSON file
with open(OUTPUT_FILE, 'w') as json_file:
    json.dump(articles, json_file, indent=4)

print(f"Extracted data has been written to {OUTPUT_FILE}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 42
#      40     if file_name.endswith('.xml'):
#      41         file_path = os.path.join(DIR_PATH, file_name)
# ---> 42         article_info = extract_article_info(file_path)
#      43         articles.append(article_info)
#      45 # Write the collected data to a JSON file
#
# Cell In[13], line 25, in extract_article_info(file_path)
#      23 # Extract title
#      24 title_element = root.find('.//article-title')
# ---> 25 title = title_element.text.strip() if title_element is not None else 'No title found'
#      27 # Extract abstract
#      28 abstract_element = root.find('.//abstract')
#
# AttributeError: 'NoneType' object has no attribute 'strip'

# %%
import os
import xml.etree.ElementTree as ET

# Path to your directory containing XML files
DIR_PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx"

# Function to extract text from all <p> (paragraph) elements nested within a given XML element
def extract_text(element):
    abstract_parts = []
    for section in element.findall('.//p'):
        if section.text:
            abstract_parts.append(section.text.strip())
    return ' '.join(abstract_parts) if abstract_parts else 'No abstract found'

# Function to extract title and abstract from an XML file
def extract_article_info(file_path):
    try:
        tree = ET.parse(file_path)
        root = tree.getroot()

        # Extract title
        title_element = root.find('.//article-title')
        title = title_element.text.strip() if title_element is not None else 'No title found'

        # Extract abstract
        abstract_element = root.find('.//abstract')
        abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

        return title, abstract
    except ET.ParseError:
        return 'Invalid XML', 'Invalid XML'

# Iterate through all XML files in the directory and extract information
for file_name in os.listdir(DIR_PATH):
    if file_name.endswith('.xml'):
        file_path = os.path.join(DIR_PATH, file_name)
        title, abstract = extract_article_info(file_path)
        print(f"File: {file_name}")
        print(f"Title: {title}")
        print(f"Abstract: {abstract}\n")
# Out:
# File: PMC1999407.xml
# Title: Open Channel Block by Ca
# Abstract: The light-activated channels of

# %%
import xml.etree.ElementTree as ET

# Path to your XML file
PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1350947.xml"

# Load and parse the XML file
tree = ET.parse(PATH)
root = tree.getroot()

# Function to extracts text form all <p> (paragraph) elements
# nested withing a given XML element.
def extract_text(element):
    abstract_parts = []
    for section in element.findall('.//p'):
        if section.text:
            abstract_parts.append(section.text.strip())
    return ' '.join(abstract_parts) if abstract_parts else 'No abstract found'

# Extract specific information
title_element = root.find('.//article-title')
title = title_element.text.strip() if title_element is not None else 'No title found'

abstract_element = root.find('.//abstract')
abstract = extract_text(abstract_element) if abstract_element is not None else 'No abstract found'

print(f"Title: {title}")
print(f"Abstract: {abstract}")
# Out:
# Title: A role for dual viral hits in causation of subacute sclerosing panencephalitis
# Abstract: Subacute sclerosing panencephalitis (SSPE) is a progressive fatal neurodegenerative disease associated with persistent infection of the central nervous system (CNS) by measles virus (MV), biased hypermutations of the viral genome affecting primarily the matrix (M) gene with the conversion of U to C and A to G bases, high titers of antibodies to MV, and infiltration of B cells and T cells into the CNS. Neither the precipitating event nor biology underlying the MV infection is understood, nor is their any satisfactory treatment. We report the creation of a transgenic mouse model that mimics the cardinal features of SSPE. This was achieved by initially infecting mice expressing the MV receptor with lymphocytic choriomeningitis virus Cl 13, a virus that transiently suppressed their immune system. Infection by MV 10 days later resulted in persistent MV infection of neurons. Analysis of brains from infected mice showed the biased U to C hypermutations in the MV M gene and T and B lymphocyte infiltration. These sera contained high titers of antibodies to MV. Thus, a small animal model is now available to both molecularly probe the pathogenesis of SSPE and to test a variety of therapies to treat the disease.

# %%
import xml.etree.ElementTree as ET

# Path to your XML file
PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1193645.xml"

# Load and parse the XML file
tree = ET.parse(PATH)
root = tree.getroot()

# Extract specific information
# Use the appropriate tags based on the XML structure
title = root.find('.//article-title').text if root.find('.//article-title') is not None else 'No title found'
abstract = root.find('.//abstract').text if root.find('.//abstract') is not None else 'No abstract found'

print(f"Title: {title}")
print(f"Abstract: {abstract}")
# Out:
# Title: Impaired Development of CD4
# Abstract: None

# %%
import xml.etree.ElementTree as ET

# Path to your XML file
PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1193645.xml"

# Load and parse the XML file
tree = ET.parse(PATH)
root = tree.getroot()

# Function to recursively find and print all tags and their text
def print_tags(element, level=0):
    indent = "  " * level
    print(f"{indent}{element.tag}: {element.text.strip() if element.text else ''}")
    for child in element:
        print_tags(child, level + 1)

# Print the structure to understand it better
print_tags(root)

# Function to extract the text content of the abstract
def extract_abstract(element):
    abstract_parts = []
    for section in element.findall('.//p'):
        if section.text:
            abstract_parts.append(section.text.strip())
    return ' '.join(abstract_parts) if abstract_parts else 'No abstract found'

# Extract specific information
title_element = root.find('.//article-title')
title = title_element.text.strip() if title_element is not None else 'No title found'

abstract_element = root.find('.//abstract')
abstract = extract_abstract(abstract_element) if abstract_element is not None else 'No abstract found'

print(f"Title: {title}")
print(f"Abstract: {abstract}")
# Out:
# article:
#   front:
#     journal-meta:
#       journal-id: J Exp Med
#       journal-id: J. Exp. Med
#       journal-title-group:
#         journal-title: The Journal of Experimental Medicine
#       issn: 0022-1007
#       issn: 1540-9538
#       publisher:
#         publisher-name: The Rockefeller University Press
#     article-meta:
#       article-id: 14699080
#       article-id: PMC1193645
#       article-id: 20020509
#       article-id: 10.1084/jem.20020509
#       article-categories:
#         subj-group:
#           subject: Article
#       title-group:
#         article-title: Impaired Development of CD4
#           sup: +
#           sup: +
#         subtitle: Increased Susceptibility to Autoimmune Disease
#       contrib-group:
#         contrib:
#           name:
#             surname: Nishibori
#             given-names: Takeaki
#         contrib:
#           name:
#             surname: Tanabe
#             given-names: Yoshinari
#         contrib:
#           name:
#             surname: Su
#             given-names: Leon
#         contrib:
#           name:
#             surname: David
#             given-names: Michael
#       aff: Division of Biological Sciences and University of California San Diego Cancer Center, University of California San Diego, La Jolla, CA 92093
#       author-notes:
#         fn:
#           p: Address correspondence to Michael David, Department of Biology, University of California San Diego, Bonner Hall 3138, 9500 Gilman Drive, La Jolla, CA 92093. Phone: (858) 822-1108; Fax: (858) 822-1106; email:
#             email: midavid@ucsd.edu
#       pub-date:
#         day: 5
#         month: 1
#         year: 2004
#       volume: 199
#       issue: 1
#       fpage: 25
#       lpage: 34
#       history:
#         date:
#           day: 1
#           month: 4
#           year: 2002
#         date:
#           day: 5
#           month: 11
#           year: 2003
#       permissions:
#         copyright-statement: Copyright © 2004, The Rockefeller University Press
#         license:
#           license-p: This article is distributed under the terms of an Attribution–Noncommercial–Share Alike–No Mirror Sites license for the first six months after the publication date (see
#             ext-link: http://www.rupress.org/terms
#             ext-link: http://creativecommons.org/licenses/by-nc-sa/4.0/
#       abstract:
#         p: Type I and II interferons (IFNs) exert opposing effects on the progression of multiple sclerosis, even though both IFNs use the signal transducer and activator of transcription 1 (STAT1) as a signaling mediator. Here we report that STAT1-deficient mice expressing a transgenic T cell receptor against myelin basic protein spontaneously develop experimental autoimmune encephalomyelitis with dramatically increased frequency. The heightened susceptibility to this autoimmune disease appears to be triggered by a reduced number as well as a functional impairment of the CD4
#           sup: +
#           sup: +
#       kwd-group:
#         kwd: STAT1
#         kwd: EAE
#         kwd: autoimmune disease
#         kwd: regulatory T cells
#     notes:
#       fn-group:
#         fn:
#           p:
#             italic: Abbreviations used in this paper:
#         fn:
#           p: T. Nishibori and Y. Tanabe contributed equally to this work.
#   body:
#     sec:
#       title: Introduction
#       p: Multiple sclerosis (MS) is a T cell–mediated, demyelinating autoimmune disease of the central nervous system characterized by T cells reactive to the major components of the myelin sheaths, such as myelin basic protein (MBP), myelin oligodendrocyte glycoprotein, and proteolipid protein (
#         xref: 1
#         xref: 2
#       p: Similarly, MS-like disease symptoms emerge in mice that express a transgenic TCR against MBP (
#         xref: 3
#         sup: +
#         sup: u
#         sup: +
#         sup: u
#         sup: b
#         xref: 4
#       p: One cell population that can mediate a protective effect has been identified as a subset of CD4
#         sup: +
#         xref: 5
#         xref: 6
#         xref: 8
#         sup: +
#         xref: 9
#         sup: +
#         sup: +
#         xref: 10
#         sup: +
#       p: Among several immunomodulatory therapies for MS treatment, IFN-β administration has become the treatment of choice. IFNs as well as other cytokines and growth factors mediate their antiviral and antiproliferative effects through the induction of immediate early response genes (
#         xref: 11
#         xref: 12
#       p: Several years ago, two labs independently generated STAT1-deficient mice to elucidate the role of STAT1 in vivo (
#         xref: 13
#         xref: 14
#         xref: 13
#         xref: 14
#         sup: −/−
#         sup: −/−
#         xref: 15
#       p: IFNs were first used in MS therapy because of their antiviral properties, as it has been observed that acute viral infection triggers the onset and clinical relapses of the disease. Initially, IFN-γ was administered, however, the IFN itself provoked significant exacerbation of the disease (
#         xref: 16
#       p: The opposing effects of IFN-α/β and IFN-γ in the progression of MS raise the intriguing question as to what role STAT1 plays in the pathogenic process because both IFNs use STAT1 as the primary mediator of their biological actions. To address this issue we used EAE as a model for MS and examined the effects of STAT1 expression on the induction and progression of this autoimmune disease.
#     sec:
#       title: Materials and Methods
#       sec:
#         title: Animals.
#         p: Wild-type and STAT1
#           sup: −/−
#           sup: b/b
#           sup: +
#           sup: +/−
#           sup: +
#           sup: u/u
#           sup: b/u
#           sup: −/−
#           sup: +
#           sup: u/u
#           sup: b/u
#       sec:
#         title: EAE Scoring and Immunizations.
#         p: Clinical symptoms of EAE were graded as follows (
#           xref: 17
#           sup: +/−
#           sup: 1
#           sup: b/u
#       sec:
#         title: Flow Cytometry and Intracellular Cytokine Staining.
#         p: FITC-labeled anti-CD4 mAb, PE-labeled anti-CD8 mAb, FITC-labeled anti-Vβ8 mAb, PE-labeled anti-CD69, biotin-conjugated anti-CD25 mAb, and biotin-conjugated anti–γ/δ TCR mAb were obtained from BD Biosciences. Biotin-conjugated anti-B220, anti-CD4 mAbs, and APC-conjugated streptavidin were purchased from eBioscience. Anti-CD3ɛ mAb (clone 2C11) and IL-2 supernatant were provided by S. Hedrick (University of California San Diego, San Diego, CA).
#         p: For immunostaining, single cell suspensions were prepared from thymus, spleen, and peripheral lymph node cells. After removing red blood cells, one million cells were resuspended in the staining buffer (PBS, 1% FCS, 0.02% NaN
#           sub: 3
#       sec:
#         title: T Cell and APC Purification.
#         p: CD4
#           sup: +
#           sup: +
#           sup: ®
#           sup: +
#           sup: +
#           sup: +
#           sup: −
#           sup: +
#           sup: +
#           sup: −
#       sec:
#         title: Carboxyfluorescein Diacetate Succinimidyl Ester (CFSE) Assays.
#         p: CFSE was obtained from Molecular Probes, Inc. Purified T cell populations of interest were washed and resuspended in PBS containing 5 μM CFSE. After incubation for 8 min, media containing serum was added and labeled cells were washed and subjected to proliferation assays. T cells (10
#           sup: 6
#           sup: 6
#           sup: +
#           sup: −
#           sup: 5
#           sup: 5
#           sup: +
#           sup: +
#       sec:
#         title: Proliferation Assays by [
#           sup: 3
#         p: Purified T cells (2 × 10
#           sup: 4
#           sup: 4
#           sup: 3
#       sec:
#         title: Adoptive T Cell Transfer.
#         p: CD4
#           sup: +
#           sup: +
#           sup: +
#           sup: +/−
#           sup: +
#           sup: b/u
#           sup: −/−
#           sup: +
#           sup: b/u
#     sec:
#       title: Results
#       sec:
#         title: STAT1-deficient Mice Are Highly Susceptible to Autoimmune Disease.
#         p: Mice transgenic for an MBP-reactive T cell receptor and of the required H-2
#           sup: u/u
#           xref: 4
#           sup: u/u
#           xref: 4
#           sup: u/u
#           sup: b/u
#           sup: b/b
#         p: To address the role of STAT1 in autoimmune disease development, we crossed these transgenic mice onto STAT1
#           sup: −/−
#           sup: u/u
#           sup: +
#           sup: −/−
#           sup: b/u
#           sup: b/u
#         p: By the age of 10 wk, 50% of these animals had developed level 5 paralysis, and by 24 wk 90% of the mice had succumbed to EAE (
#           xref: Fig. 1
#           sup: +
#           sup: +/−
#           sup: b/u
#           sup: +
#           sup: +/−
#           sup: b/u
#           sup: u/u
#           xref: 4
#         fig:
#           label: Figure 1.
#           caption:
#             p: Spontaneous EAE development in wild-type and STAT1-deficient mice. (A) TCR
#               sup: +
#               sup: −/−
#               sup: b/u
#               sup: +
#               sup: +/−
#               sup: b/u
#               sup: +
#               sup: −/−
#               sup: u/u
#               sup: +
#               sup: +/−
#               sup: u/u
#           graphic:
#         p: Identical to mice of H-2
#           sup: b/u
#           sup: +
#           sup: −/−
#           sup: u/u
#           sup: +
#           sup: +/−
#           sup: u/u
#           sup: +
#           sup: +/−
#           sup: u/u
#           xref: 4
#           xref: Fig. 1
#       sec:
#         title: Increased IFN-γ Production and CD69 Up-regulation in STAT1-deficient Paralyzed Mice.
#         p: T cells expressing the transgenic TCR can be identified by immunostaining with Vβ8-specific antibodies (
#           xref: 4
#           sup: +
#           sup: −/−
#           sup: b/u
#           xref: Fig. 2
#           sup: +
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           sup: −
#           sup: +
#           sup: +
#           sup: −/−
#           sup: b/u
#           xref: Fig. 2
#         fig:
#           label: Figure 2.
#           caption:
#             p: Flow cytometric analysis of wild-type, asymptomatic, or paralyzed STAT1-deficient mice. (A) Cells derived from lymph nodes of wild-type, asymptomatic, or paralyzed STAT1-deficient animals were stained for CD4, CD69, and Vβ8. Horizontal axis represents Vβ8 staining, vertical axis corresponds to CD4 (top) or CD69 (bottom) staining of CD8
#               sup: −
#               sup: +
#               sup: −
#           graphic:
#       sec:
#         title: Increased Lymphocyte/Macrophage Infiltration in the Central Nervous System (CNS) of STAT1-deficient Paralyzed Mice.
#         p: To ensure that the observed paralysis was indeed the consequence of an inflammatory response of the CNS, brains and spines were removed from asymptomatic or paralyzed STAT1-deficient TCR
#           sup: +
#           sup: b/u
#           xref: Fig. 3
#           sup: +
#           sup: +
#           sup: −/−
#           sup: b/u
#         fig:
#           label: Figure 3.
#           caption:
#             p: Immunohistological analysis of CNS tissue from asymptomatic and paralyzed STAT1-deficient mice. Brains and spines were removed from asymptomatic or paralyzed (level 5) STAT1-deficient mice and fixed in formaldehyde. Paraffin-embedded sections were stained with hematoxylin and eosin.
#           graphic:
#       sec:
#         title: Hyperproliferation of STAT1-deficient CD4
#           sup: +
#         p: Total splenocytes isolated from STAT1-deficient animals have been shown to hyperproliferate in vitro (
#           xref: 15
#           sup: +
#           sup: −/−
#           xref: Fig. 4
#         fig:
#           label: Figure 4.
#           caption:
#             p: Proliferation of wild-type and STAT1-deficient CD4
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: −/−
#               sup: b/u
#               sup: +
#               sup: +/−
#               sup: b/u
#               sup: +/−
#               sup: b/u
#           graphic:
#         p: To confirm this difference in cell growth in T cells expressing the transgenic TCR and in response to the dominant autoantigen of EAE, CD4
#           sup: +
#           sup: +
#           sup: −/−
#           sup: b/u
#           sup: +
#           sup: +/−
#           sup: b/u
#           sup: +/−
#           sup: b/u
#           sup: +
#           sup: +
#           sup: −/−
#           sup: b/u
#           xref: Fig. 4
#       sec:
#         title: Reduced Number of CD4
#           sup: +
#           sup: +
#         p: The dramatically increased frequency of spontaneous EAE development in TCR
#           sup: MBP
#           sup: MBP
#           xref: 4
#           sup: +
#           sup: +
#           xref: 9
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           xref: Fig. 5
#           sup: +
#           sup: +
#           sup: −/−
#         fig:
#           label: Figure 5.
#           caption:
#             p: (A and B) Flow cytometric analysis of thymocytes in wild-type and STAT1-deficient mice. Cells derived from thymi of wild-type or STAT1-deficient animals were stained for CD4, CD8, and CD25. The ratio of CD4
#               sup: +
#               sup: −
#               sup: +
#               sup: +
#               sup: −
#           graphic:
#       sec:
#         title: Wild-type CD4
#           sup: +
#         p: The finding of a reduced CD4
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           sup: +
#           sup: +
#           sup: −/−
#           sup: −/−
#           sup: +
#           sup: +
#           sup: −/−
#           xref: Fig. 6
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           xref: Fig. 6
#           xref: Fig. 6
#           sup: +
#         fig:
#           label: Figure 6.
#           caption:
#             p: Effect of wild-type CD4
#               sup: +
#               sup: +
#               sup: −/−
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: −/−
#               sup: +
#               sup: −/−
#               sup: +
#           graphic:
#           graphic:
#           graphic:
#       sec:
#         title: Wild-type, but Not STAT1-deficient CD4
#           sup: +
#           sup: +
#         p: Next, we wanted to ensure that the reduced rate of [
#           sup: 3
#           sup: +
#           sup: +
#           sup: +
#           sup: −/−
#           sup: −/−
#           sup: +
#           xref: Fig. 6
#           sup: +
#           xref: Fig. 6
#           sup: +
#           xref: Fig. 6
#         p: CD4
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           xref: Fig. 6
#           sup: +
#           sup: +
#           sup: +
#           xref: Fig. 6
#         p: To further corroborate these results, we also added increasing numbers of purified wild-type or STAT1-deficient CD4
#           sup: +
#           sup: +
#           sup: +
#           sup: −
#           xref: Fig. 7
#           sup: +
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           sup: −
#           sup: −/−
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#           sup: −
#           sup: +
#           sup: +
#         fig:
#           label: Figure 7.
#           caption:
#             p: STAT1-deficient CD4
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: +
#               sup: −
#               sup: +
#               sup: −
#               sup: +
#               sup: +
#               sup: +
#               sup: −
#               sup: +
#               sup: +
#           graphic:
#       sec:
#         title: Adoptive Transfer of Wild-type CD4
#           sup: +
#           sup: +
#           sup: −/−
#           sup: +
#         p: To determine whether the observed deficiencies in CD4
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +/−
#           sup: b/u
#           sup: +
#           sup: −/−
#           sup: b/u
#           xref: Table I
#           sup: +
#           sup: +/−
#           sup: b/u
#           sup: +
#           sup: +
#           sup: +
#           sup: +
#           sup: +/−
#           sup: b/u
#         table-wrap:
#           label: Table I.
#           caption:
#             p: Protection of STAT1
#               sup: −/−
#               sup: +
#           table:
#             thead:
#               tr:
#                 th: Transferred WT cells
#                 th: Lethality after 17 wk (%)
#             tbody:
#               tr:
#                 td: No transfer
#                 td: 24/30 (80)
#               tr:
#                 td: CD4
#                   sup: +
#                   sup: 6
#                 td: 2/6 (32)
#               tr:
#                 td: CD4
#                   sup: +
#                   sup: +
#                   sup: 4
#                 td: 1/6 (16)
#     sec:
#       title: Discussion
#       p: The immunomodulatory functions of IFNs have long provoked interest in the role of these cytokines in the development or treatment of numerous autoimmune disorders, particularly of MS (
#         xref: 18
#         xref: 16
#         sup: +
#         xref: 1
#         xref: 19
#         sup: +
#         sup: +
#         sup: −/−
#         sup: b/u
#       p: Previous studies have shown that STAT1-deficient cells lack the expression of several caspase family members (
#         xref: 15
#         xref: 20
#         sup: MBP
#         sup: +
#         sup: −/−
#       p: In mice carrying the transgene for the MBP-directed TCR, ∼95% of the CD4
#         sup: +
#         sup: MBP
#         sup: +
#         sup: MBP
#         sup: −/−
#         xref: 4
#         sup: +
#         sup: +
#         sup: +
#         sup: +
#         sup: +
#         sup: +
#         sup: −
#         xref: 9
#         xref: 21
#         sup: +
#         xref: 7
#         xref: 22
#         xref: 26
#       p: Crosses of TCR
#         sup: MBP
#         sup: +
#         sup: +
#         sup: +
#         sup: +
#         sup: +
#         sup: +
#         sup: −/−
#         sup: +
#         sup: +
#         sup: +
#         sup: −
#         sup: −/−
#         sup: +
#         sup: +
#         sup: +
#         sup: −/−
#       p: Many key aspects of the origin of regulatory T cells remain unsolved. B7 and CD28 are required elements in the generation of CD4
#         sup: +
#         sup: +
#         xref: 27
#         xref: 28
#         xref: 29
#         sup: −/−
#         xref: 30
#         xref: 16
#         xref: 31
#         xref: 32
#         xref: 33
#         sup: +
#         sup: +
#         sup: +
#         sup: −
#         xref: 34
#   back:
#     ack:
#       p: TCR
#         sup: MBP
#       p: This work was supported by National Institutes of Health grant CA80105 (to M. David) and a grant from the National Multiple Sclerosis Society (to M. David).
#     ref-list:
#       ref:
#         label: 1
#         mixed-citation: Steinman, L.
#           year: 1996
#           source: Cell.
#           volume: 85
#           fpage: 299
#           pub-id: 8616884
#       ref:
#         label: 2
#         mixed-citation: Steinman, L.
#           year: 1999
#           source: Neuron.
#           volume: 24
#           fpage: 511
#           pub-id: 10595504
#       ref:
#         label: 3
#         mixed-citation: Goverman, J., A. Woods, L. Larson, L.P. Weiner, L. Hood, and D.M. Zaller.
#           year: 1993
#           source: Cell.
#           volume: 72
#           fpage: 551
#           pub-id: 7679952
#       ref:
#         label: 4
#         mixed-citation: Lafaille, J.J., K. Nagashima, M. Katsuki, and S. Tonegawa.
#           year: 1994
#           source: Cell.
#           volume: 78
#           fpage: 399
#           pub-id: 7520367
#       ref:
#         label: 5
#         mixed-citation: Sakaguchi, S., N. Sakaguchi, M. Asano, M. Itoh, and M. Toda.
#           year: 1995
#           source: J. Immunol.
#           volume: 155
#           fpage: 1151
#           pub-id: 7636184
#       ref:
#         label: 6
#         mixed-citation: Suri-Payer, E., A.Z. Amar, A.M. Thornton, and E.M. Shevach.
#           year: 1998
#           source: J. Immunol.
#           volume: 160
#           fpage: 1212
#           pub-id: 9570536
#       ref:
#         label: 7
#         mixed-citation: Shevach, E.M.
#           year: 2001
#           sup: +
#           sup: +
#           source: J. Exp. Med.
#           volume: 193
#           fpage: F41
#           pub-id: 11390442
#       ref:
#         label: 8
#         mixed-citation: Thornton, A.M., and E.M. Shevach.
#           year: 1998
#           sup: +
#           sup: +
#           source: J. Exp. Med.
#           volume: 188
#           fpage: 287
#           pub-id: 9670041
#       ref:
#         label: 9
#         mixed-citation: Van de Keere, F., and S. Tonegawa.
#           year: 1998
#           sup: +
#           source: J. Exp. Med.
#           volume: 188
#           fpage: 1875
#           pub-id: 9815265
#       ref:
#         label: 10
#         mixed-citation: Thornton, A.M., and E.M. Shevach.
#           year: 2000
#           source: J. Immunol.
#           volume: 164
#           fpage: 183
#           pub-id: 10605010
#       ref:
#         label: 11
#         mixed-citation: Schindler, C., and J.E. Darnell, Jr.
#           year: 1995
#           source: Annu. Rev. Biochem.
#           volume: 64
#           fpage: 621
#           pub-id: 7574495
#       ref:
#         label: 12
#         mixed-citation: Muller, M., C. Laxton, J. Briscoe, C. Schindler, T. Improta, J.E. Darnell, Jr., G.R. Stark, and I.M. Kerr.
#           year: 1993
#           source: EMBO J.
#           volume: 12
#           fpage: 4221
#           pub-id: 7693454
#       ref:
#         label: 13
#         mixed-citation: Meraz, M.A., J.M. White, K.C.F. Sheehan, E.A. Bach, S.J. Rodig, A.S. Dighe, D.H. Kaplan, J.K. Riley, A.C. Greenlund, D. Campbell, et al.
#           year: 1996
#           italic: Stat1
#           source: Cell.
#           volume: 84
#           fpage: 431
#           pub-id: 8608597
#       ref:
#         label: 14
#         mixed-citation: Durbin, J.E., R. Hackenmiller, M.C. Simon, and D.E. Levy.
#           year: 1996
#           italic: Stat1
#           source: Cell.
#           volume: 84
#           fpage: 443
#           pub-id: 8608598
#       ref:
#         label: 15
#         mixed-citation: Lee, C.K., E. Smith, R. Gimeno, R. Gertner, and D.E. Levy.
#           year: 2000
#           source: J. Immunol.
#           volume: 164
#           fpage: 1286
#           pub-id: 10640742
#       ref:
#         label: 16
#         mixed-citation: Karp, C.L., C.A. Biron, and D.N. Irani.
#           year: 2000
#           source: Immunol. Today.
#           volume: 21
#           fpage: 24
#           pub-id: 10637555
#       ref:
#         label: 17
#         mixed-citation: Baron, J.L., J.A. Madri, N.H. Ruddle, G. Hashim, and C.A. Janeway, Jr.
#           year: 1993
#           source: J. Exp. Med.
#           volume: 177
#           fpage: 57
#           pub-id: 7678116
#       ref:
#         label: 18
#         mixed-citation: Biron, C.A.
#           year: 2001
#           source: Immunity.
#           volume: 14
#           fpage: 661
#           pub-id: 11420036
#       ref:
#         label: 19
#         mixed-citation: Durbin, J.E., A. Fernandez-Sesma, C.K. Lee, T.D. Rao, A.B. Frey, T.M. Moran, S. Vukmanovic, A. Garcia-Sastre, and D.E. Levy.
#           year: 2000
#           source: J. Immunol.
#           volume: 164
#           fpage: 4220
#           pub-id: 10754318
#       ref:
#         label: 20
#         mixed-citation: Kumar, A., M. Commane, T.W. Flickinger, C.M. Horvath, and G.R. Stark.
#           year: 1997
#           source: Science.
#           volume: 278
#           fpage: 1630
#           pub-id: 9374464
#       ref:
#         label: 21
#         mixed-citation: Kuniyasu, Y., T. Takahashi, M. Itoh, J. Shimizu, G. Toda, and S. Sakaguchi.
#           year: 2000
#           source: Int. Immunol.
#           volume: 12
#           fpage: 1145
#           pub-id: 10917889
#       ref:
#         label: 22
#         mixed-citation: Maloy, K.J., and F. Powrie.
#           year: 2001
#           source: Nat. Immunol.
#           volume: 2
#           fpage: 816
#           pub-id: 11526392
#       ref:
#         label: 23
#         mixed-citation: Shevach, E.M., R.S. McHugh, A.M. Thornton, C. Piccirillo, K. Natarajan, and D.H. Margulies.
#           year: 2001
#           source: Adv. Exp. Med. Biol.
#           volume: 490
#           fpage: 21
#           pub-id: 11505971
#       ref:
#         label: 24
#         mixed-citation: O'Garra, A., L. Steinman, and K. Gijbels.
#           year: 1997
#           source: Curr. Opin. Immunol.
#           volume: 9
#           fpage: 872
#           pub-id: 9492992
#       ref:
#         label: 25
#         mixed-citation: Shevach, E.M.
#           year: 2000
#           source: Annu. Rev. Immunol.
#           volume: 18
#           fpage: 423
#           pub-id: 10837065
#       ref:
#         label: 26
#         mixed-citation: Sakaguchi, S.
#           year: 2000
#           source: Cell.
#           volume: 101
#           fpage: 455
#           pub-id: 10850488
#       ref:
#         label: 27
#         mixed-citation: Salomon, B., D.J. Lenschow, L. Rhee, N. Ashourian, B. Singh, A. Sharpe, and J.A. Bluestone.
#           year: 2000
#           source: Immunity.
#           volume: 12
#           fpage: 431
#           pub-id: 10795741
#       ref:
#         label: 28
#         mixed-citation: Grewal, I.S., H.G. Foellmer, K.D. Grewal, H. Wang, W.P. Lee, D. Tumas, C.A. Janeway, Jr., and R.A. Flavell.
#           year: 2001
#           source: Immunity.
#           volume: 14
#           fpage: 291
#           pub-id: 11290338
#       ref:
#         label: 29
#         mixed-citation: Papiernik, M., M.L. de Moraes, C. Pontoux, F. Vasseur, and C. Penit.
#           year: 1998
#           source: Int. Immunol.
#           volume: 10
#           fpage: 371
#           pub-id: 9620592
#       ref:
#         label: 30
#         mixed-citation: Segal, B.M., B.K. Dwyer, and E.M. Shevach.
#           year: 1998
#           source: J. Exp. Med.
#           volume: 187
#           fpage: 537
#           pub-id: 9463404
#       ref:
#         label: 31
#         mixed-citation: Willenborg, D.O., S. Fordham, C.C. Bernard, W.B. Cowden, and I.A. Ramshaw.
#           year: 1996
#           source: J. Immunol.
#           volume: 157
#           fpage: 3223
#           pub-id: 8871615
#       ref:
#         label: 32
#         mixed-citation: Chu, C.Q., S. Wittmer, and D.K. Dalton.
#           year: 2000
#           source: J. Exp. Med.
#           volume: 192
#           fpage: 123
#           pub-id: 10880533
#       ref:
#         label: 33
#         mixed-citation: Kumar, V., and E. Sercarz.
#           year: 2001
#           source: Immunol. Rev.
#           volume: 182
#           fpage: 113
#           pub-id: 11722628
#       ref:
#         label: 34
#         mixed-citation: McHugh, R.S., M.J. Whitters, C.A. Piccirillo, D.A. Young, E.M. Shevach, M. Collins, and M.C. Byrne.
#           year: 2002
#           source: Immunity.
#           volume: 16
#           fpage: 311
#           pub-id: 11869690
# Title: Impaired Development of CD4
# Abstract: Type I and II interferons (IFNs) exert opposing effects on the progression of multiple sclerosis, even though both IFNs use the signal transducer and activator of transcription 1 (STAT1) as a signaling mediator. Here we report that STAT1-deficient mice expressing a transgenic T cell receptor against myelin basic protein spontaneously develop experimental autoimmune encephalomyelitis with dramatically increased frequency. The heightened susceptibility to this autoimmune disease appears to be triggered by a reduced number as well as a functional impairment of the CD4

# %%
import xml.etree.ElementTree as ET

# Path to your XML file
PATH = "/Users/jacobhessels/KU/bachelor/data/PMC001xxxxxx/PMC1193645.xml"

# Load and parse the XML file
tree = ET.parse(PATH)
root = tree.getroot()

# Function to extract the text content of the abstract
def extract_abstract(element):
    abstract_parts = []
    for section in element.findall('.//abstract//p'):
        if section.text:
            abstract_parts.append(section.text.strip())
    return ' '.join(abstract_parts) if abstract_parts else 'No abstract found'

# Extract specific information
title = root.find('.//article-title').text if root.find('.//article-title') is not None else 'No title found'
abstract = extract_abstract(root.find('.//abstract')) if root.find('.//abstract') is not None else 'No abstract found'

print(f"Title: {title}")
print(f"Abstract: {abstract}")
# Out:
# Title: Impaired Development of CD4
# Abstract: No abstract found

# %%
import xml.etree.ElementTree as ET

# Load and parse the XML file
tree = ET.parse(PATH)
root = tree.getroot()

# Function to recursively print all tags
def print_tags(element, level=0):
    indent = "  " * level
    print(f"{indent}{element.tag}")
    for child in element:
        print_tags(child, level + 1)

# Start printing from the root
print_tags(root)
# Out:
# article
#   front
#     journal-meta
#       journal-id
#       journal-id
#       journal-title-group
#         journal-title
#       issn
#       issn
#       publisher
#         publisher-name
#     article-meta
#       article-id
#       article-id
#       article-id
#       article-id
#       article-categories
#         subj-group
#           subject
#       title-group
#         article-title
#           sup
#           sup
#         subtitle
#       contrib-group
#         contrib
#           name
#             surname
#             given-names
#         contrib
#           name
#             surname
#             given-names
#         contrib
#           name
#             surname
#             given-names
#         contrib
#           name
#             surname
#             given-names
#       aff
#       author-notes
#         fn
#           p
#             email
#       pub-date
#         day
#         month
#         year
#       volume
#       issue
#       fpage
#       lpage
#       history
#         date
#           day
#           month
#           year
#         date
#           day
#           month
#           year
#       permissions
#         copyright-statement
#         license
#           license-p
#             ext-link
#             ext-link
#       abstract
#         p
#           sup
#           sup
#       kwd-group
#         kwd
#         kwd
#         kwd
#         kwd
#     notes
#       fn-group
#         fn
#           p
#             italic
#         fn
#           p
#   body
#     sec
#       title
#       p
#         xref
#         xref
#       p
#         xref
#         sup
#         sup
#         sup
#         sup
#         sup
#         xref
#       p
#         sup
#         xref
#         xref
#         xref
#         sup
#         xref
#         sup
#         sup
#         xref
#         sup
#       p
#         xref
#         xref
#       p
#         xref
#         xref
#         xref
#         xref
#         sup
#         sup
#         xref
#       p
#         xref
#       p
#     sec
#       title
#       sec
#         title
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#       sec
#         title
#         p
#           xref
#           sup
#           sup
#           sup
#       sec
#         title
#         p
#         p
#           sub
#       sec
#         title
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#       sec
#         title
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#       sec
#         title
#           sup
#         p
#           sup
#           sup
#           sup
#       sec
#         title
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#     sec
#       title
#       sec
#         title
#         p
#           sup
#           xref
#           sup
#           xref
#           sup
#           sup
#           sup
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#         p
#           xref
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#         fig
#           label
#           caption
#             p
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#           graphic
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#           xref
#       sec
#         title
#         p
#           xref
#           sup
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#         fig
#           label
#           caption
#             p
#               sup
#               sup
#               sup
#           graphic
#       sec
#         title
#         p
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#           sup
#         fig
#           label
#           caption
#             p
#           graphic
#       sec
#         title
#           sup
#         p
#           xref
#           sup
#           sup
#           xref
#         fig
#           label
#           caption
#             p
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#           graphic
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#       sec
#         title
#           sup
#           sup
#         p
#           sup
#           sup
#           xref
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#         fig
#           label
#           caption
#             p
#               sup
#               sup
#               sup
#               sup
#               sup
#           graphic
#       sec
#         title
#           sup
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#           xref
#           sup
#         fig
#           label
#           caption
#             p
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#           graphic
#           graphic
#           graphic
#       sec
#         title
#           sup
#           sup
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#           sup
#           xref
#           sup
#           xref
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#           xref
#         p
#           sup
#           sup
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#         fig
#           label
#           caption
#             p
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#               sup
#           graphic
#       sec
#         title
#           sup
#           sup
#           sup
#           sup
#         p
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           xref
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#           sup
#         table-wrap
#           label
#           caption
#             p
#               sup
#               sup
#           table
#             thead
#               tr
#                 th
#                 th
#             tbody
#               tr
#                 td
#                 td
#               tr
#                 td
#                   sup
#                   sup
#                 td
#               tr
#                 td
#                   sup
#                   sup
#                   sup
#                 td
#     sec
#       title
#       p
#         xref
#         xref
#         sup
#         xref
#         xref
#         sup
#         sup
#         sup
#         sup
#       p
#         xref
#         xref
#         sup
#         sup
#         sup
#       p
#         sup
#         sup
#         sup
#         sup
#         sup
#         xref
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         xref
#         xref
#         sup
#         xref
#         xref
#         xref
#       p
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#         sup
#       p
#         sup
#         sup
#         xref
#         xref
#         xref
#         sup
#         xref
#         xref
#         xref
#         xref
#         xref
#         sup
#         sup
#         sup
#         sup
#         xref
#   back
#     ack
#       p
#         sup
#       p
#     ref-list
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           sup
#           sup
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           sup
#           sup
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           sup
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           italic
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           italic
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id
#       ref
#         label
#         mixed-citation
#           year
#           source
#           volume
#           fpage
#           pub-id

# %%
print(root)
# Out:
# <Element 'article' at 0x7f77bc62e7f0>
